# %% [markdown]
# ## Experiment No 8
# ## Tools for EDA-Study of numpy library
# ## Name:Atharva Jadhav
# ## PRN:25070123027
# ## Batch: ENTC A2

# %%
# Why NumPy?
# Faster than lists
# Used for numerical computation
# Base for Pandas

# %%
# Declaration of NumPy
import numpy as np
a=np.array([10,20,30,40])
b=np.array([[1,2,3],[9,8,7]])## 2 square brackects are required
print(a)
print(b)
# Out:
# [10 20 30 40]
# [[1 2 3]
#  [9 8 7]]

# %% [markdown]
# ## In built functions in NumPy

# %%
# To check dimenstions
print(a.ndim)
print(b.ndim)
# Out:
# 1
# 2

# %%
# Shape of A & B
print(a.shape)
print(b.shape)
# Out:
# (4,)
# (2, 3)

# %%
# To check the DataType
print(a.dtype)
print(b.dtype)
# Out:
# int64
# int64

# %%
# To use np as zeros
np.zeros((1,3))
# Out:
# array([[0., 0., 0.]])

# %%
# To use np as ones
np.ones((2,4))
# Out:
# array([[1., 1., 1., 1.],
#        [1., 1., 1., 1.]])

# %%
# To use np as eye (Diagonal Matrix)
np.eye((3))
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
# To use np as arranging (Print 1 to 12 with spacing 3)
np.arange(1,12,3)
# Out:
# array([ 1,  4,  7, 10])

# %%
np.linspace(0,1,5)
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
c=a*2
d=a+5
print(c)
print(d)
# Out:
# [20 40 60 80]
# [15 25 35 45]

# %%
a+5
# Out:
# array([15, 25, 35, 45])

# %%
# To use np as mean
np.mean(a)
# Out:
# np.float64(25.0)

# %%
# To use np as median
np.median(a)
# Out:
# np.float64(25.0)

# %%
# To use np as maximum
np.max(a)
# Out:
# np.int64(40)

# %%
# To use np as minimum
np.min(a)
# Out:
# np.int64(10)

# %%
# To use np as sum
np.sum(a)
# Out:
# np.int64(100)
